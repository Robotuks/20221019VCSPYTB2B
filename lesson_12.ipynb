# %%
import pandas as pd

# %%
# df = pd.read_csv('LT.csv')
df = pd.read_csv('LT.csv', parse_dates=['date'])

# %%
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country
# 0                   Friendly   Moscow  Soviet Union
# 1                   Friendly   Moscow  Soviet Union
# 2                   Friendly   Moscow  Soviet Union
# ...

# %%
df.describe()
# Out:
#        home_score  away_score
# count  367.000000  367.000000
# mean     1.547684    0.986376
# std      1.349879    1.172233
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      1.000000    1.000000
# 75%      2.000000    1.000000
# max      5.000000    7.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        367 non-null    datetime64[ns]
#  1   home_team   367 non-null    object
#  2   away_team   367 non-null    object
#  3   home_score  367 non-null    int64
#  4   away_score  367 non-null    int64
#  5   tourniment  367 non-null    object
#  6   city        367 non-null    object
#  7   country     367 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 23.1+ KB

# %%
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country
# 0                   Friendly   Moscow  Soviet Union
# 1                   Friendly   Moscow  Soviet Union
# 2                   Friendly   Moscow  Soviet Union
# ...

# %% [markdown]
# ## Filtering

# %%
df[ df['away_team'] == 'Lithuania' ]
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 4   1979-07-30      Russia  Lithuania           2           0
# 5   1979-08-01     Belarus  Lithuania           0           2
# ..         ...         ...        ...         ...         ...
# 354 2019-03-25  Azerbaijan  Lithuania           0           0
# 357 2019-06-10      Serbia  Lithuania           4           1
# 358 2019-06-10      Serbia  Lithuania           4           1
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
#
#                   tourniment      city       country
# 0                   Friendly    Moscow  Soviet Union
# 1                   Friendly    Moscow  Soviet Union
# 2                   Friendly    Moscow  Soviet Union
# ...

# %%
df['away_team'] == 'Lithuania'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 362    False
# 363     True
# 364     True
# 365    False
# 366    False
# Name: away_team, Length: 367, dtype: bool

# %%
df[ [True if i % 5 == 0 else False for i in range(len(df)) ]  ]
# Out:
#           date   home_team   away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan   Lithuania           0           0
# 5   1979-08-01     Belarus   Lithuania           0           2
# 10  1992-04-14     Austria   Lithuania           4           0
# 15  1992-07-12      Latvia   Lithuania           2           3
# 20  1992-10-28   Lithuania      Latvia           1           1
# ..         ...         ...         ...         ...         ...
# 345 2018-10-14   Lithuania  Montenegro           1           4
# 350 2018-11-20      Serbia   Lithuania           4           1
# 355 2019-06-07   Lithuania  Luxembourg           1           1
# 360 2019-09-07   Lithuania     Ukraine           0           3
# 365 2019-10-14   Lithuania      Serbia           1           2
#
#                        tourniment      city       country
# 0                        Friendly    Moscow  Soviet Union
# 5                        Friendly    Moscow  Soviet Union
# ...

# %%
df[ (df['away_team'] == 'Lithuania') &  ( df['city'] == 'Belgrade' ) ]
# Out:
#           date home_team  away_team  home_score  away_score  \
# 152 2005-09-03    Serbia  Lithuania           2           0
# 183 2008-10-11    Serbia  Lithuania           3           0
# 349 2018-11-20    Serbia  Lithuania           4           1
# 350 2018-11-20    Serbia  Lithuania           4           1
# 357 2019-06-10    Serbia  Lithuania           4           1
# 358 2019-06-10    Serbia  Lithuania           4           1
#
#                        tourniment      city                country
# 152  FIFA World Cup qualification  Belgrade  Serbia and Montenegro
# 183  FIFA World Cup qualification  Belgrade                 Serbia
# 349           UEFA Nations League  Belgrade                 Serbia
# 350           UEFA Nations League  Belgrade                 Serbia
# 357       UEFA Euro qualification  Belgrade                 Serbia
# 358       UEFA Euro qualification  Belgrade                 Serbia

# %%
# Bitwise operators
# and = &
# or = | 
# not = ~
# in = .isin()

# %%
df[ df['away_team'].isin( ['Montenegro', 'Serbia'] ) ]
# Out:
#           date  home_team   away_team  home_score  away_score  \
# 154 2005-10-08  Lithuania      Serbia           0           2
# 195 2009-10-14  Lithuania      Serbia           2           1
# 339 2018-09-07  Lithuania      Serbia           0           1
# 340 2018-09-07  Lithuania      Serbia           0           1
# 345 2018-10-14  Lithuania  Montenegro           1           4
# 346 2018-10-14  Lithuania  Montenegro           1           4
# 365 2019-10-14  Lithuania      Serbia           1           2
# 366 2019-10-14  Lithuania      Serbia           1           2
#
#                        tourniment         city    country
# 154  FIFA World Cup qualification      Vilnius  Lithuania
# 195  FIFA World Cup qualification  Marijampol?  Lithuania
# 339           UEFA Nations League      Vilnius  Lithuania
# 340           UEFA Nations League      Vilnius  Lithuania
# 345           UEFA Nations League      Vilnius  Lithuania
# ...

# %%
df[ (df['away_team'] == 'Lithuania') & (df['city'] == 'Belgrade') ]
# Out:
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score, tourniment, city, country]
# Index: []

# %%
# filter when Lithuania played in Kaunas or Vilnius
df[ df['city'].isin(['Vilnius','Kaunas']) & (df['home_team'] == 'Lithuania') ]
# Out:
#           date  home_team away_team  home_score  away_score  \
# 17  1992-09-02  Lithuania   Georgia           1           0
# 18  1992-09-23  Lithuania   Denmark           0           0
# 19  1992-10-14  Lithuania  Slovakia           0           1
# 20  1992-10-28  Lithuania    Latvia           1           1
# 26  1993-04-14  Lithuania   Albania           3           1
# ..         ...        ...       ...         ...         ...
# 360 2019-09-07  Lithuania   Ukraine           0           3
# 361 2019-09-10  Lithuania  Portugal           1           5
# 362 2019-09-10  Lithuania  Portugal           1           5
# 365 2019-10-14  Lithuania    Serbia           1           2
# 366 2019-10-14  Lithuania    Serbia           1           2
#
#                        tourniment     city    country
# 17                       Friendly   Kaunas  Lithuania
# 18   FIFA World Cup qualification  Vilnius  Lithuania
# 19                       Friendly  Vilnius  Lithuania
# ...

# %%
# How many games Lithuania played away in 2018
len( df[ (df['away_team'] == 'Lithuania') & ( df['date'].dt.year == 2018 ) ] )
# df[ (df['away_team'] == 'Lithuania') & ( pd.DatetimeIndex(df['date']).year==2018 ) ]
# Out:
# 14

# %%
df[ (df['away_team'] == 'Lithuania') & ( df['date'].dt.year == 2018 ) & (df['away_score'] >= 1)  ]
# Out:
#           date home_team  away_team  home_score  away_score  \
# 329 2018-03-27   Armenia  Lithuania           0           1
# 330 2018-03-27   Armenia  Lithuania           0           1
# 349 2018-11-20    Serbia  Lithuania           4           1
# 350 2018-11-20    Serbia  Lithuania           4           1
#
#               tourniment      city  country
# 329             Friendly   Yerevan  Armenia
# 330             Friendly   Yerevan  Armenia
# 349  UEFA Nations League  Belgrade   Serbia
# 350  UEFA Nations League  Belgrade   Serbia

# %%
df = df.rename(columns={'tourniment': 'tournament'} )
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tournament     city       country
# 0                   Friendly   Moscow  Soviet Union
# 1                   Friendly   Moscow  Soviet Union
# 2                   Friendly   Moscow  Soviet Union
# ...

# %%
# how many games Lithuania played in each tournament
df['tournament'].value_counts()
# Out:
# Friendly                           127
# FIFA World Cup qualification        90
# UEFA Euro qualification             87
# Baltic Cup                          40
# UEFA Nations League                 12
# Cyprus International Tournament      8
# Malta International Tournament       3
# Name: tournament, dtype: int64

# %%
df.groupby('tournament').count()
# Out:
#                                  date  home_team  away_team  home_score  \
# tournament
# Baltic Cup                         40         40         40          40
# Cyprus International Tournament     8          8          8           8
# FIFA World Cup qualification       90         90         90          90
# Friendly                          127        127        127         127
# Malta International Tournament      3          3          3           3
# UEFA Euro qualification            87         87         87          87
# UEFA Nations League                12         12         12          12
#
#                                  away_score  city  country
# tournament
# Baltic Cup                               40    40       40
# Cyprus International Tournament           8     8        8
# FIFA World Cup qualification             90    90       90
# Friendly                                127   127      127
# Malta International Tournament            3     3        3
# ...

# %%
df[ 'goal_sum' ] = df['home_score'] + df['away_score']
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tournament     city       country  goal_sum
# 0                   Friendly   Moscow  Soviet Union         0
# 1                   Friendly   Moscow  Soviet Union         5
# ...

# %%
df[ 'goal_diff' ] = df['home_score'] - df['away_score']
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tournament     city       country  goal_sum  goal_diff
# 0                   Friendly   Moscow  Soviet Union         0          0
# 1                   Friendly   Moscow  Soviet Union         5          5
# ...

# %%
len (df[ df['goal_diff'] == 0 ] )
# Out:
# 73

# %%
min(df['goal_diff'])
# Out:
# -7

# %%
# df[ (df['home_team'] == 'Lithuania') & (df['goal_diff'] == min(df['goal_diff']) ) ]
# df[ (df['home_team'] == 'Lithuania')  ].sort_values('goal_diff')
# Option 1
df_home_LT = df[ (df['home_team'] == 'Lithuania')  ]
df_home_LT[  (df_home_LT['goal_diff'] == min(df_home_LT['goal_diff']) ) ]
# Out:
#           date  home_team away_team  home_score  away_score  \
# 108 2000-10-11  Lithuania   Hungary           1           6
#
#                        tournament    city    country  goal_sum  goal_diff
# 108  FIFA World Cup qualification  Kaunas  Lithuania         7         -5

# %%
# Option 2 , gives only single result
df[ (df['home_team'] == 'Lithuania')  ].sort_values('goal_diff').iloc[0]
# Out:
# date                   2000-10-11 00:00:00
# home_team                        Lithuania
# away_team                          Hungary
# home_score                               1
# away_score                               6
# tournament    FIFA World Cup qualification
# city                                Kaunas
# country                          Lithuania
# goal_sum                                 7
# goal_diff                               -5
# Name: 108, dtype: object

# %%
df[ (df['away_team'] == 'Lithuania') & (df['goal_diff'] > 0) ]
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 1   1979-07-22     Georgia  Lithuania           5           0
# 4   1979-07-30      Russia  Lithuania           2           0
# 6   1979-08-05      Russia  Lithuania           2           1
# 10  1992-04-14     Austria  Lithuania           4           0
# 13  1992-06-03     Albania  Lithuania           1           0
# ..         ...         ...        ...         ...         ...
# 352 2019-03-22  Luxembourg  Lithuania           2           1
# 357 2019-06-10      Serbia  Lithuania           4           1
# 358 2019-06-10      Serbia  Lithuania           4           1
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
#
#                        tournament             city       country  goal_sum  \
# 1                        Friendly           Moscow  Soviet Union         5
# ...

# %%
df[ (df['away_team'] == 'Lithuania') & (df['goal_diff'] < 0) ]
# Out:
#           date        home_team  away_team  home_score  away_score  \
# 2   1979-07-24       Azerbaijan  Lithuania           0           1
# 5   1979-08-01          Belarus  Lithuania           0           2
# 15  1992-07-12           Latvia  Lithuania           2           3
# 16  1992-08-12           Latvia  Lithuania           1           2
# 21  1993-02-20           Latvia  Lithuania           1           2
# 40  1994-09-07          Ukraine  Lithuania           0           2
# 42  1994-11-16         Slovenia  Lithuania           1           2
# 47  1995-05-20          Estonia  Lithuania           0           7
# 51  1995-08-16          Estonia  Lithuania           0           1
# 56  1996-07-08           Latvia  Lithuania           1           2
# 69  1997-04-30    Liechtenstein  Lithuania           0           2
# 78  1997-10-11  North Macedonia  Lithuania           1           2
# 79  1998-04-21           Latvia  Lithuania           1           2
# ...

# %%
df[ (df['country'] == 'Lithuania') & (df['goal_diff'] > 0) ]
# Out:
#           date  home_team               away_team  home_score  away_score  \
# 8   1991-11-15  Lithuania                 Estonia           4           1
# 17  1992-09-02  Lithuania                 Georgia           1           0
# 26  1993-04-14  Lithuania                 Albania           3           1
# 37  1994-07-29  Lithuania                 Estonia           3           0
# 38  1994-07-31  Lithuania                  Latvia           1           0
# 46  1995-05-17  Lithuania                  Greece           2           1
# 49  1995-06-07  Lithuania                Slovenia           2           1
# 53  1995-10-11  Lithuania                 Estonia           5           0
# 61  1996-10-05  Lithuania                 Iceland           2           0
# 62  1996-10-09  Lithuania           Liechtenstein           2           1
# 64  1996-11-03  Lithuania               Indonesia           4           0
# 71  1997-07-09  Lithuania                 Estonia           2           1
# ...

# %%
df[ (df['country'] == 'Lithuania') & (df['goal_diff'] < 0) ]
# Out:
#           date  home_team               away_team  home_score  away_score  \
# 19  1992-10-14  Lithuania                Slovakia           0           1
# 27  1993-05-18  Lithuania                 Ukraine           1           2
# 28  1993-05-25  Lithuania        Northern Ireland           0           1
# 29  1993-06-02  Lithuania                   Spain           0           2
# 30  1993-06-16  Lithuania     Republic of Ireland           0           1
# 45  1995-04-26  Lithuania                   Italy           0           1
# 52  1995-09-06  Lithuania                 Ukraine           1           3
# 68  1997-04-02  Lithuania                 Romania           0           1
# 76  1997-09-10  Lithuania     Republic of Ireland           1           2
# 87  1998-08-19  Lithuania                 Belarus           0           3
# 92  1999-03-31  Lithuania                 Estonia           1           2
# 98  1999-09-04  Lithuania          Czech Republic           0           4
# ...

# %%
df[ (df['away_team'] == 'Lithuania') & (df['goal_diff'] == 0) ]
# Out:
#           date               home_team  away_team  home_score  away_score  \
# 0   1979-07-20              Kyrgyzstan  Lithuania           0           0
# 7   1990-05-27                 Georgia  Lithuania           2           2
# 11  1992-04-28        Northern Ireland  Lithuania           2           2
# 12  1992-05-20                 Moldova  Lithuania           1           1
# 14  1992-07-11                 Estonia  Lithuania           1           1
# 24  1993-03-30                Slovakia  Lithuania           2           2
# 25  1993-03-31                  Poland  Lithuania           1           1
# 31  1993-07-03                  Latvia  Lithuania           0           0
# 57  1996-07-09                 Estonia  Lithuania           1           1
# 58  1996-07-31                 Belarus  Lithuania           2           2
# 70  1997-06-11                 Iceland  Lithuania           0           0
# 74  1997-08-20     Republic of Ireland  Lithuania           0           0
# ...

# %%
df[ (df['home_team'] == 'Lithuania') & (df['goal_diff'] == 0) & (df['country'] == 'Lithuania') ]
# Out:
#           date  home_team      away_team  home_score  away_score  \
# 9   1991-11-17  Lithuania         Latvia           1           1
# 18  1992-09-23  Lithuania        Denmark           0           0
# 20  1992-10-28  Lithuania         Latvia           1           1
# 35  1994-04-20  Lithuania         Israel           1           1
# 44  1995-03-29  Lithuania        Croatia           0           0
# 50  1995-07-29  Lithuania        Belarus           1           1
# 86  1998-08-16  Lithuania        Moldova           1           1
# 88  1998-09-05  Lithuania       Scotland           0           0
# 89  1998-10-10  Lithuania  Faroe Islands           0           0
# 118 2001-09-01  Lithuania          Italy           0           0
# 145 2004-10-13  Lithuania          Spain           0           0
# 155 2005-10-12  Lithuania        Belgium           1           1
# 197 2010-06-18  Lithuania         Latvia           0           0
# ...
